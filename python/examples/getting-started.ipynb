# %%
from nozzle.client import Client
from nozzle.util import to_hex

client = Client("grpc://127.0.0.1:1602")

# %%
df = client.get_sql("select * from logs limit 1", read_all=True).to_pandas()
df = df.map(to_hex)
df
# Out:
# ---------------------------------------------------------------------------
# FlightUnavailableError                    Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = client.get_sql("select * from logs limit 1", read_all=True).to_pandas()
#       2 df = df.map(to_hex)
#       3 df
#
# File ~/nozzle/project-nozzle/python/nozzle/client.py:28, in Client.get_sql(self, query, read_all)
#      24 cmd = any_command.SerializeToString()
#      27 flight_descriptor = flight.FlightDescriptor.for_command(cmd)
# ---> 28 info = self.conn.get_flight_info(flight_descriptor)
#      29 reader = self.conn.do_get(info.endpoints[0].ticket)
#      31 if read_all:
#
# File ~/nozzle/project-nozzle/python/.venv/lib/python3.12/site-packages/pyarrow/_flight.pyx:1600, in pyarrow._flight.FlightClient.get_flight_info()
#
# File ~/nozzle/project-nozzle/python/.venv/lib/python3.12/site-packages/pyarrow/_flight.pyx:68, in pyarrow._flight.check_flight_status()
#
# FlightUnavailableError: Flight returned unavailable error, with message: failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:1602: Failed to connect to remote host: Connection refused

# %%
client.get_sql("select count(*) block_count from blocks")
