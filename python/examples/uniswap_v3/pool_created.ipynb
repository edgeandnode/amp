# %% [markdown]
# # Extracting `PoolCreated` events from Uniswap
#
# This example shows how `evm_decode` and `evm_topic` can be used to find events and decode them.

# %%
from nozzle.client import Client
from nozzle.util import to_hex
import os.path

# client_url = os.getenv("NOZZLE_URL", "grpc://127.0.0.1:1602")
client_url = "grpc+tcp://34.122.177.97:80"
client = Client(client_url)
print(client)
# Out:
# <nozzle.client.Client object at 0x127d7aab0>

# %%
# The address of the Uniswap factory contract
uniswap_factory = "1F98431c8aD98523631AE4a59f267346ea31F984"

factory_path = "abis/factory.json"
pool_path = "abis/pool.json"

df = client.get_sql("select * from logs limit 1", read_all=True).to_pandas()

# %%
df
# Out:
#                                           block_hash  block_num  \
# 0  b':\x1f\xbaZ\xbd\x9dAEyD\xe9\x1e\xd0\x97\xe09\...      52029
#
#                   timestamp  tx_index  \
# 0 2015-08-08 06:22:55+00:00         0
#
#                                              tx_hash  \
# 0  b'!\x8bc-\x93#qG\x8d\x1a\xe5\xa0\x16 \xeb\xab\...
#
#                                              address  \
# 0  b'Ud\x88l\xa2\xc5\x18\xd1\x96N_\xce\xa4\xf4#\x...
#
#                                               topic0  \
# 0  b'\xa6i~\x97Nj2\x0fEC\x90\xbe\x03\xf7IU\xe8\x9...
#
#                                               topic1 topic2 topic3 data  \
# 0  b'MyFirstCoin\x00\x00\x00\x00\x00\x00\x00\x00\...   None   None  b''
#
#    block_index  index  call_index  ordinal
# 0            0      0           1        8

# %%
client.get_sql("select count(*) logs_count from logs", read_all=True)
# Out:
# pyarrow.Table
# logs_count: int64 not null
# ----
# logs_count: [[3686440789]]

# %%
client.get_sql("select count(*) blocks_count, min(block_num) first_block, max(block_num) latest_block from blocks", read_all=True)
# Out:
# pyarrow.Table
# blocks_count: int64
# first_block: uint64
# latest_block: uint64
# ----
# blocks_count: [[19820001]]
# first_block: [[0]]
# latest_block: [[19820000]]

# %%
import time

def elapsed(start):
    return round(time.time() - start, 4)

# Processes a SQL query using the provided client and prints the timings.
# The first received batched is printed out, the rest only report the row count.
def process_query(client, query):
    print(query)
    start = time.time()

    result_stream = client.get_sql(query)
    print('time to establish stream: ', elapsed(start), 's')

    total_events = 0
    try:
        batch = next(result_stream)
        print('time for first batch ', elapsed(start), 's')
        total_events += batch.num_rows
        print(batch.to_pandas().map(to_hex))

        batch_start = time.time()

        for batch in result_stream:
            total_events += batch.num_rows
            print('received batch of ', batch.num_rows, ' rows in ', elapsed(batch_start), 's')
            batch_start = time.time()

        print('total rows: ', total_events)
        print('total time to consume the stream: ', elapsed(start), 's')
        print('rows/s: ', total_events / elapsed(start))

    except StopIteration:
        print("No more batches available in the result stream.")

# %%
from nozzle.util import Abi
import time

# Load a JSON ABI and get the 'PoolCreated' event
factory = Abi(factory_path)

pool_created_sig = factory.events["PoolCreated"].signature()

pool_created_query = f"""
    select pc.block_num,
       pc.dec['pool'] as pool,
       pc.dec['token0'] as token0,
       pc.dec['token1'] as token1,
       pc.dec['fee'] as fee,
       pc.dec['tickSpacing'] as tick_spacing
      from (select l.block_num,
                   evm_decode(l.topic1, l.topic2, l.topic3, l.data, '{pool_created_sig}') as dec
              from logs l
             where l.address = arrow_cast(x'{uniswap_factory}', 'FixedSizeBinary(20)')
               and l.topic0 = evm_topic('{pool_created_sig}')) pc
"""

# Explain analyze
# print(client.get_sql("explain analyze " + query, read_all=True).to_pandas()['plan'][0])

# %%
print(client.get_sql("explain analyze " + pool_created_query, read_all=True).to_pandas()['plan'][0])
# Out:
# ProjectionExec: expr=[block_num@0 as block_num, get_field(dec@1, pool) as pool, get_field(dec@1, token0) as token0, get_field(dec@1, token1) as token1, get_field(dec@1, fee) as fee, get_field(dec@1, tickSpacing) as tick_spacing], metrics=[output_rows=22259, elapsed_compute=954.9µs]
#   ProjectionExec: expr=[block_num@0 as block_num, evm_decode(topic1@3, topic2@4, topic3@5, data@6, PoolCreated(address indexed token0,address indexed token1,uint24 indexed fee,int24 tickSpacing,address pool)) as dec], metrics=[output_rows=22259, elapsed_compute=11.880099ms]
#     CoalesceBatchesExec: target_batch_size=8192, metrics=[output_rows=22259, elapsed_compute=867.993896ms]
#       FilterExec: address@1 = 31,152,67,28,138,217,133,35,99,26,228,165,159,38,115,70,234,49,249,132 AND topic0@2 = 120,60,202,28,4,18,221,13,105,94,120,69,104,201,109,162,233,194,47,249,137,53,122,46,139,29,155,43,78,107,113,24, metrics=[output_rows=22259, elapsed_compute=50.555775404s]
#         ParquetExec: file_groups={30 groups: [[logs/000000000.parquet:0..23483953, logs/000991001.parquet:0..62654042, logs/001982002.parquet:0..116728492, logs/002973003.parquet:0..396780555, logs/003927063.parquet:0..51750012, ...], [logs/005286247.parquet:299098426..333273056, logs/005373909.parquet:0..319241289, logs/005447695.parquet:0..350484571, logs/005515156.parquet:0..351400108, logs/005578395.parquet:0..344469925, ...], [logs/006368796.parquet:220028833..254994328, logs/006433034.parquet:0..302945634, logs/006505652.parquet:0..322991095, logs/006583774.parquet:0..336326357, logs/006665951.parquet:0..329741242, ...], [logs/007685476.parquet:100938178..349466781, logs/007756169.parquet:0..365131812, logs/007818908.parquet:0..367029688, logs/007928008.parquet:0..366636991, logs/007988620.parquet:0..376578585, ...], [logs/008699758.parquet:251428560..334819877, logs/008758046.parquet:0..339550838, logs/008815321.parquet:0..294063333, logs/008864709.parquet:0..244569047, logs/008904168.parquet:0..93356833, ...], ...]}, projection=[block_num, address, topic0, topic1, topic2, topic3, data], predicate=address@5 = 31,152,67,28,138,217,133,35,99,26,228,165,159,38,115,70,234,49,249,132 AND topic0@6 = 120,60,202,28,4,18,221,13,105,94,120,69,104,201,109,162,233,194,47,249,137,53,122,46,139,29,155,43,78,107,113,24, pruning_predicate=CASE WHEN address_null_count@2 = address_row_count@3 THEN false ELSE address_min@0 <= 31,152,67,28,138,217,133,35,99,26,228,165,159,38,115,70,234,49,249,132 AND 31,152,67,28,138,217,133,35,99,26,228,165,159,38,115,70,234,49,249,132 <= address_max@1 END AND CASE WHEN topic0_null_count@6 = topic0_row_count@7 THEN false ELSE topic0_min@4 <= 120,60,202,28,4,18,221,13,105,94,120,69,104,201,109,162,233,194,47,249,137,53,122,46,139,29,155,43,78,107,113,24 AND 120,60,202,28,4,18,221,13,105,94,120,69,104,201,109,162,233,194,47,249,137,53,122,46,139,29,155,43,78,107,113,24 <= topic0_max@5 END, required_guarantees=[address in (31,152,67,28,138,217,133,35,99,26,228,165,159,38,115,70,234,49,249,132), topic0 in (120,60,202,28,4,18,221,13,105,94,120,69,104,201,109,162,233,194,47,249,137,53,122,46,139,29,155,43,78,107,113,24)], metrics=[output_rows=3686440789, elapsed_compute=30ns, row_groups_pruned_statistics=0, pushdown_rows_filtered=0, file_open_errors=0, row_groups_pruned_bloom_filter=0, page_index_rows_filtered=0, file_scan_errors=0, row_groups_matched_bloom_filter=0, num_predicate_creation_errors=0, bytes_scanned=107189685394, row_groups_matched_statistics=3828, predicate_evaluation_errors=0, time_elapsed_scanning_until_data=353.559630886s, time_elapsed_scanning_total=3595.514469577s, time_elapsed_opening=10.022165381s, pushdown_eval_time=1.196µs, page_index_eval_time=112.70823ms, time_elapsed_processing=1544.870610355s]

# %%
process_query(client, pool_created_query)
# Out:
#     select pc.block_num,
#        pc.dec['pool'] as pool,
#        pc.dec['token0'] as token0,
#        pc.dec['token1'] as token1,
#        pc.dec['fee'] as fee,
#        pc.dec['tickSpacing'] as tick_spacing
#       from (select l.block_num,
#                    evm_decode(l.topic1, l.topic2, l.topic3, l.data, 'PoolCreated(address indexed token0,address indexed token1,uint24 indexed fee,int24 tickSpacing,address pool)') as dec
#               from logs l
#              where l.address = arrow_cast(x'1F98431c8aD98523631AE4a59f267346ea31F984', 'FixedSizeBinary(20)')
#                and l.topic0 = evm_topic('PoolCreated(address indexed token0,address indexed token1,uint24 indexed fee,int24 tickSpacing,address pool)')) pc
#
# time to establish stream:  0.1103 s
# time for first batch  110.3418 s
#      block_num                                        pool  \
# 0     13033076  0x6d58c0a8a97839a4b038ffe06f6198662da1979e
# 1     13033312  0xa3fb45696ac592cf4187798b6b17316c5d93460d
# 2     13033783  0xd5d15f5d0d9dbb27db974159f11ce4b0c64a030f
# 3     13034053  0x03041c580199f865d5ab69427990a4570a80533b
# 4     13034130  0x4a8cd9303a1d5d2d732c06c76f45ed083dcc3d5b
# ..         ...                                         ...
# 749   13433415  0x756a7b8cd482e6a35e3b45a9e575f6bd7e32e681
# 750   13434383  0x42127ae25a276b4ece5024086bdf5d13619ef60c
# 751   13434958  0x0158de06d8bee85b063a733e1f5f01b3be3cc3f1
# 752   13436189  0x7c082bf85e01f9bb343dbb460a14e51f67c58cfb
# 753   13438340  0xcd30a875e88a1f4df35104ab3145f2869072f4e9
#
#                                          token0  \
# 0    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1    0x0beb3fb60f69b36886b3398a052667d2d9c044ea
# 2    0xa3f44edde71883b23ba71269e8602e6c0d5b85ce
# 3    0x765974827a0a85023aa54464dd1de39d960b0a72
# 4    0x148958884544a8ad7c4895e6ffe2723932e0523a
# ..                                          ...
# 749  0x5d843fa9495d23de997c394296ac7b4d721e841c
# 750  0x00b17e5c7f4096ec7c67b05e41f77a724b927e62
# 751  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 752  0x865377367054516e17014ccded1e7d814edc9ce4
# 753  0x5e17a18b3984f1d0db9efa8e13a1091ab7adcb30
#
#                                          token1    fee  tick_spacing
# 0    0xd5525d397898e5502075ea5e830d8914f6f0affe  10000           200
# 1    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   3000            60
# 2    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   3000            60
# 3    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  10000           200
# 4    0xdac17f958d2ee523a2206206994597c13d831ec7    500            10
# ..                                          ...    ...           ...
# 749  0xdac17f958d2ee523a2206206994597c13d831ec7  10000           200
# 750  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  10000           200
# 751  0xd5dfcceab617dbed25c790da556593c3ca7bf335   3000            60
# 752  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48   3000            60
# 753  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   3000            60
#
# [754 rows x 6 columns]
# received batch of  556  rows in  1.7003 s
# received batch of  705  rows in  2.0679 s
# received batch of  1470  rows in  1.6751 s
# received batch of  567  rows in  0.7499 s
# received batch of  2420  rows in  0.1412 s
# received batch of  669  rows in  2.7571 s
# received batch of  912  rows in  0.0861 s
# received batch of  1244  rows in  0.6984 s
# received batch of  678  rows in  0.1608 s
# received batch of  1258  rows in  0.1312 s
# received batch of  831  rows in  0.757 s
# received batch of  1638  rows in  0.0998 s
# received batch of  911  rows in  0.1314 s
# received batch of  762  rows in  0.5874 s
# received batch of  628  rows in  0.0479 s
# received batch of  1075  rows in  0.6111 s
# received batch of  2284  rows in  2.2441 s
# received batch of  1248  rows in  0.3379 s
# received batch of  1649  rows in  0.2834 s
# total rows:  22259
# total time to consume the stream:  125.6351 s
# rows/s:  177.17182538956072

# %%
pool_abi = Abi(pool_path)
swap_sig = pool_abi.events["Swap"].signature()


query = f"""
with pc as ({pool_created_query})
select sw.block_num, sw.tx_hash,
       sw.dec['sender'] as sender,
       sw.dec['recipient'] as recipient,
       sw.dec['amount0'] as amount0,
       sw.dec['amount1'] as amount1,
       sw.dec['sqrtPriceX96'] as sqrt_price_x96,
       sw.dec['liquidity'] as liquidity,
       sw.dec['tick'] as tick
  from (select sl.block_num, sl.tx_hash,
               evm_decode(sl.topic1, sl.topic2, sl.topic3, sl.data, '{swap_sig}') as dec
          from pc, logs sl
         where sl.address = pc.pool
           and sl.block_num >= pc.block_num
           and sl.topic0 = evm_topic('{swap_sig}')) as sw
"""

# Note: This will download all the swaps.
# process_query(client, query)

# Explain
# print(client.get_sql("explain " + query, read_all=True).to_pandas()['plan'][1])

# %%
# This is used to benchmark the same work as the original query, but incurring less network trafic.
agg_query = f'''select count(*), max(a.amount0), max(a.liquidity), sum(a.amount0) from ({query}) a'''
process_query(client, agg_query)
# Out:
# select count(*), max(a.amount0), max(a.liquidity), sum(a.amount0) from (
# with pc as (
#     select pc.block_num,
#        pc.dec['pool'] as pool,
#        pc.dec['token0'] as token0,
#        pc.dec['token1'] as token1,
#        pc.dec['fee'] as fee,
#        pc.dec['tickSpacing'] as tick_spacing
#       from (select l.block_num,
#                    evm_decode(l.topic1, l.topic2, l.topic3, l.data, 'PoolCreated(address indexed token0,address indexed token1,uint24 indexed fee,int24 tickSpacing,address pool)') as dec
#               from logs l
#              where l.address = arrow_cast(x'1F98431c8aD98523631AE4a59f267346ea31F984', 'FixedSizeBinary(20)')
#                and l.topic0 = evm_topic('PoolCreated(address indexed token0,address indexed token1,uint24 indexed fee,int24 tickSpacing,address pool)')) pc
# )
# select sw.block_num, sw.tx_hash,
#        sw.dec['sender'] as sender,
#        sw.dec['recipient'] as recipient,
#        sw.dec['amount0'] as amount0,
#        sw.dec['amount1'] as amount1,
#        sw.dec['sqrtPriceX96'] as sqrt_price_x96,
#        sw.dec['liquidity'] as liquidity,
#        sw.dec['tick'] as tick
#   from (select sl.block_num, sl.tx_hash,
#                evm_decode(sl.topic1, sl.topic2, sl.topic3, sl.data, 'Swap(address indexed sender,address indexed recipient,int256 amount0,int256 amount1,uint160 sqrtPriceX96,uint128 liquidity,int24 tick)') as dec
#           from pc, logs sl
#          where sl.address = pc.pool
#            and sl.block_num >= pc.block_num
#            and sl.topic0 = evm_topic('Swap(address indexed sender,address indexed recipient,int256 amount0,int256 amount1,uint160 sqrtPriceX96,uint128 liquidity,int24 tick)')) as sw
# ) a
# time to establish stream:  0.1277 s
# time for first batch  255.2618 s
#    COUNT(*)                                 MAX(a.amount0)  \
# 0  52813141  384417821897828797475164770296333371772502528
#
#                       MAX(a.liquidity)  \
# 0  19863405339384158564563182385400765
#
#                                   SUM(a.amount0)
# 0  237019549802128447264294256359939778437671764
# total rows:  1
# total time to consume the stream:  255.2679 s
# rows/s:  0.003917451462776376

# %%
graph_token_lock_manager = '0xFCf78AC094288D7200cfdB367A8CD07108dFa128'
